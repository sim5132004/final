# %%
import pandas as pd
import cx_Oracle
import pandas as pdb
connection = cx_Oracle.connect("party/party@192.168.30.240:1521/xe")

query = """select * from PlACEINFO"""

place_df = pd.read_sql(query, con=connection)
# Out:
# C:\Users\tj-bu\AppData\Local\Temp\ipykernel_13044\4165351655.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   place_df = pd.read_sql(query, con=connection)

# %%
place_df.head(4)
# Out:
#    ID 카테고리   소분류        제목                       주소               전화번호  \
# 0   2   관광  역사문화    강화 석수문  인천 강화군 강화읍 고비고개로19번길 12       032-930-4571
# 1   4   관광  역사문화    강화 전등사    인천 강화군 길상면 전등사로 37-41       032-937-0125
# 2  10   관광    기타      애관극장           인천 중구 개항로 63-2       032-761-7177
# 3  17   관광  체험관광  강화 화문석마을      인천 강화군 송해면 전망대로 452  032-934-2290,6245
#
#            경도         위도                                         애완동물동반가능정보  \
# 0  126.474572  37.745366  가능 (단, 개목줄 착용, 배설물 처리를 위한 비닐봉지 등을 구비한 이용객에 한하여...
# 1  126.484406  37.632160                              불가(전등사 관람은 목줄과 함께 가능)
# 2  126.629807  37.472359                                                 불가
# 3  126.458513  37.799880                                                 불가
#
#       주차시설  ...  판매품목  편의시설  대표메뉴 포장가능여부  입실시간  퇴실시간  부대시설  \
# 0  있음 (무료)  ...  None  None  None   None  None  None  None
# 1  있음 (유료)  ...  None  None  None   None  None  None  None
# 2       있음  ...  None  None  None   None  None  None  None
# 3  있음 (무료)  ...  None  None  None   None  None  None  None
#
#                                               키워드리스트  \
# 0  강화/154,수문/123,강화산성/113,서문/92,강화도/65,강화읍/49,벚꽃/...
# 1  전등사/376,강화/163,강화도/69,삼랑성/66,대웅보전/47,대웅전/46,주차...
# 2  극장/230,애관/184,영화/153,인천/115,영화관/66,상영/47,역사/38...
# 3  화문석/299,마을/158,체험/141,강화/139,강화도/57,왕골/55,만들기/...
#
#                                               이미지주소1  \
# 0  http://tong.visitkorea.or.kr/cms/resource/72/2...
# 1  http://post.phinf.naver.net/MjAxOTAzMTRfMTg3/M...
# 2  http://imgnews.naver.net/image/032/2022/04/18/...
# 3  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
#
#                                               이미지주소2
# 0  http://post.phinf.naver.net/MjAxOTExMjdfMjU1/M...
# 1  http://post.phinf.naver.net/MjAxODAxMDZfMTUz/M...
# 2  http://imgnews.naver.net/image/5650/2021/12/01...
# 3  http://tong.visitkorea.or.kr/cms/resource/12/2...
#
# [4 rows x 26 columns]

# %%
place_df['카테고리']=='음식'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 879     True
# 880    False
# 881    False
# 882     True
# 883     True
# Name: 카테고리, Length: 884, dtype: bool

# %%
filter_df=place_df[place_df['카테고리'] == '음식']

# %%
filter_df
# Out:
#       ID 카테고리     소분류                  제목                        주소  \
# 132  492   음식      한식               돈비어천가            인천 중구 개항로 53-1
# 133  497   음식      한식               명품삼계탕          인천 미추홀구 독정이로 112
# 134  499   음식      한식               바다해물탕             인천 남동구 하촌로 58
#
#                                                 이미지주소1  \
# 132  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# 133  http://post.phinf.naver.net/MjAxNzA2MTVfMTgx/M...
# 134  https://mp-seoul-image-production-s3.mangoplat...
# 135  https://image-logo.alba.kr/%2Fdata_image2%2Fco...
# 136  http://tong.visitkorea.or.kr/cms/resource/17/1...
# ..                                                 ...
# 871  https://ldb-phinf.pstatic.net/20211028_252/163...
# 878  http://imgnews.naver.net/image/5385/2015/07/02...
# 879  http://imgnews.naver.net/image/5239/2019/06/10...
# 882  https://search.pstatic.net/common/?src=http%3A...
# 883  https://mp-seoul-image-production-s3.mangoplat...
#
#                                                 이미지주소2
# 132  https://mp-seoul-image-production-s3.mangoplat...
# 133  http://imgnews.naver.net/image/468/2019/07/10/...
# 134  https://sitem.ssgcdn.com/47/16/75/item/1000303...
# 135  https://image-logo.alba.kr/%2Fdata_image2%2Fco...
# 136  http://tong.visitkorea.or.kr/cms/resource/05/1...
# ..                                                 ...
# 871  https://mp-seoul-image-production-s3.mangoplat...
# 878  http://imgnews.naver.net/image/5535/2019/05/06...
# 879  http://tong.visitkorea.or.kr/cms/resource/75/2...
# 882  https://images.unsplash.com/photo-159705214538...
# 883  https://d2uja84sd90jmv.cloudfront.net/posts/k5...
#
# [249 rows x 26 columns]

# %%
filter_df.to_csv("음식.csv")

# %%
import codecs
# from konlpy.tag import Twitter
from konlpy.tag import Okt
# utf-8 인코딩으로 파일을 열고 글자를 출력하기 --- (※1)
# fp = codecs.open("hong.txt", "r", encoding="utf-8")
# fp = codecs.open("./data/박근혜_국정연설문_2016.txt", "r", encoding="utf-8")
fp = codecs.open("음식.csv", "r", encoding="utf-8")
text = fp.read()
# 텍스트를 한 줄씩 처리하기 --- (※2)
# twitter = Twitter()
okt = Okt()
word_dic = {}
lines = text.split("\r\n")

# %%
from konlpy.tag import Okt

okt = Okt()
word_dic = {}

for line in lines:
    malist = okt.pos(line, norm=True, stem=True)
    for word in malist:
        if word[1] == "Noun" and len(word[0]) >= 2:  # 두 글자 이상인 명사만 고려
            if word[0] not in word_dic:
                word_dic[word[0]] = 0
            word_dic[word[0]] += 1

# 가장 많이 사용된 명사 상위 50개만 추출
top_n = 50
keys = sorted(word_dic.items(), key=lambda x: x[1], reverse=True)[:top_n]

for word, count in keys:
    print("{0}({1})".format(word, count))
print()
# Out:
# 음식(580)
# 인천(412)
# 위치(380)
# 한식(367)
# 가능(281)
# 추가(237)
# 맛집(233)
# 기타(226)
# 이웃(219)
# 메뉴(217)
# 남녀(215)
# 복사(215)
# 본문(211)
# 기능(211)
# 브레이크(210)
# 타임(210)
# 주문(207)
# 시간(202)
# 구분(201)
# 무료(186)
# 주차(184)
# 내부(169)
# 방문(164)
# 정말(160)
# 번길(153)
# 휴무(150)
# 인천광역시(150)
# 식당(139)
# 생각(133)
# 거리(128)
# 바로(126)
# 정도(123)
# 진짜(115)
# 미추홀(115)
# 메뉴판(111)
# 식사(108)
# 문화(105)
# 고기(104)
# 남동구(100)
# 반찬(99)
# 하나(95)
# 연수구(92)
# 저희(91)
# 추천(91)
# 표기(90)
# 영문(88)
# 사진(87)
# 국물(86)
# 중구(84)
# 우리(84)

# %%
from konlpy.tag import Okt
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 from konlpy.tag import Okt
# ----> 2 from wordcloud import WordCloud
#       3 from collections import Counter
#       4 import matplotlib.pyplot as plt
#
# File ~\anaconda3\lib\site-packages\wordcloud\__init__.py:1
# ----> 1 from .wordcloud import (WordCloud, STOPWORDS, random_color_func,
#       2                         get_single_color_func)
#       3 from .color_from_image import ImageColorGenerator
#       5 __all__ = ['WordCloud', 'STOPWORDS', 'random_color_func',
#       6            'get_single_color_func', 'ImageColorGenerator',
#       7            '__version__']
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:19
#      17 import sys
#      18 import colorsys
# ---> 19 import matplotlib
#      20 import numpy as np
#      21 from operator import itemgetter
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:144
#     140 from packaging.version import parse as parse_version
#     142 # cbook must import matplotlib only within function
#     143 # definitions, so it is safe to import from it here.
# --> 144 from . import _api, _version, cbook, _docstring, rcsetup
#     145 from matplotlib.cbook import sanitize_sequence
#     146 from matplotlib._api import MatplotlibDeprecationWarning
#
# File ~\anaconda3\lib\site-packages\matplotlib\rcsetup.py:27
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# File ~\anaconda3\lib\site-packages\matplotlib\colors.py:51
#      49 from numbers import Number
#      50 import re
# ---> 51 from PIL import Image
#      52 from PIL.PngImagePlugin import PngInfo
#      54 import matplotlib as mpl
#
# File ~\anaconda3\lib\site-packages\PIL\Image.py:50
#      45     ElementTree = None
#      47 # VERSION was removed in Pillow 6.0.0.
#      48 # PILLOW_VERSION was removed in Pillow 9.0.0.
#      49 # Use __version__ instead.
# ---> 50 from . import (
#      51     ExifTags,
#      52     ImageMode,
#      53     TiffTags,
#      54     UnidentifiedImageError,
#      55     __version__,
#      56     _plugins,
#      57 )
#      58 from ._binary import i32le, o32be, o32le
#      59 from ._util import DeferredError, is_path
#
# ImportError: cannot import name 'UnidentifiedImageError' from 'PIL' (unknown location)

# %%
# Word Cloud 생성 및 시각화
font_path = 'NanumBarunGothic.ttf'
wordcloud = WordCloud(
    font_path=font_path,
    width=800,
    height=800,
    background_color="white"
)

# 수정: word_list 대신 word_dic
wordcloud.generate_from_frequencies(word_dic)

array = wordcloud.to_array()

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.axis('off')  # 축 제거
plt.show()
fig.savefig('wordcloud.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Word Cloud 생성 및 시각화
#       2 font_path = 'NanumBarunGothic.ttf'
# ----> 3 wordcloud = WordCloud(
#       4     font_path=font_path,
#       5     width=800,
#       6     height=800,
#       7     background_color="white"
#       8 )
#      10 # 수정: word_list 대신 word_dic
#      11 wordcloud.generate_from_frequencies(word_dic)
#
# NameError: name 'WordCloud' is not defined
